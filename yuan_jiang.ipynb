# %% [markdown]
# ### INF 510 Fall 2019 Final Project Submission

# %% [markdown]
# 1.	**The names of team member(s)**:
#
#     Yuan Jiang

# %% [markdown]
# 2.	**How to run your code (what command-line switches they are, what happens when you invoke the code, etc.)**
#
#     This project requires the following packages:
#     - pandas, numpy, seaborn, json, argparse, copy, urllib, requests, beautifulsoup and xpinyin
#
#     To run this project, make sure the above packages are installed, and then simply clone the repo at https://github.com/Sevinta/inf510 and execute this notebook

# %% [markdown]
# 3.	**Any major “gotchas” to the code (i.e. things that don’t work, go slowly, could be improved, etc.)**
#
#     The api I used in milestone2 to get the longitude and latitude of the communities has a limit every day. So if you run yuan_jiang_hw5.py with -source = remote for several times a day, it will print "get error" which means this api reach the limit. You can try to run it the next day.

# %% [markdown]
# 4.  **Anything else you feel is relevant to the grading of your project your project.**
#
#     No.

# %% [markdown]
# 5. **What did you set out to study?  (i.e. what was the point of your project?  This should be close to your Milestone 1 assignment, but if you switched gears or changed things, note it here.)**
#
#    The communities is from six area in Shanghai. They are the top 150 popular communities of each area. The dataset contains the area, name, longitude, latitude, and the average price(RMB) per square meter. The result_price.cvs contains the six areas' all communities' average price in November and December.
#
#    In milestone 1 I want to the information of second-hand house in Shanghai including the name, the address, the total price, the price per square meter and the district of each house. But I find that a lot of house will come from the same community and this will make the data set very unbalanced. Because it is high likely that the houses in the top 100(e.g.) almost come from the same community. So I change my data to the communities instead of the houses.
#
#    What's more, the api to get the lat and lng has a limit per day, so I reduced data volume.  I planed to scrape 10 area in Shanghai, now I scrape just 7.

# %% [markdown]
# 6. **What did you Discover/what were your conclusions (i.e. what were your findings?  Were your original assumptions confirmed, etc.?)**
#
#     The average price of the six areas differ from each other a lot. Huangpu, which is the center of Shanghai has the highest average price. But it's max price is low than four of the areas. Here are old houses with a sense of age. Due to regional reasons, the price is high, but the subsequent development should not be comparable to emerging development areas such as Pudong. Comparing the price in November and December, the price is increasing. Comparing the two months' price with the average price this year, all of the areas' communities' price are increasing. All in all, the house price in Shanghai is increasing and new commercial districts are gradually surpassing the old town.

# %% [markdown]
# 7. **What difficulties did you have in completing the project?**
#
#     It's difficult to read the html code, sometimes I even could not find where the data is. It's long and very complex. What's more, executing the script file with command line really confused me. I seldom use command line before so to understand the mean of '-source == remote' cost me a lot of time.

# %% [markdown]
# 8. **What skills did you wish you had while you were doing the project?**
#
#     I hope I could know more about html and know more about how to use the command line.

# %% [markdown]
# 9. **What would you do “next” to expand or augment the project?**
#
#     I want to design a Web page that mark every communiy in result_community.csv on the map. When we right click the mark of community, the name, address and the average price of the community will be shown in the InfoWindow. What's more, I would present the charts and the heatmap in this project on the Web page too. So that people can clearly find the overall price information of each area and compare which is more suitable for them.

# %%
import sys
sys.path.append('src/')
import charts0

# %%
charts0.avg_price()

# %% [markdown]
# It's the overall house prices in Shanghai in November and December. The old town Huangpu has the highest average house price because tourism is very developed in this area. And school districts in this area are good so the price is the highest.

# %%
charts0.Average_price()

# %%
charts0.Min_price()

# %%
charts0.Max_price()

# %% [markdown]
# The max prices are really high!

# %%
charts0.Variable_distribution()

# %% [markdown]
# Most of the house price of the communities is in 50000~100000 RMB

# %%
charts0.heatmap()

# %% [markdown]
# The bigger the points are, the higher average house price are. You can learn the overall distribution of house prices in the heatmap.
